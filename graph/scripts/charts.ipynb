# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

data = [
  {
    "v": 10,
    "a": 45,
    "i": 10,
    "m": 3047.0,
    "s": 485.8899463870394
  },
  {
    "v": 20,
    "a": 190,
    "i": 20,
    "m": 3950.4,
    "s": 1990.565798962697
  },
  {
    "v": 30,
    "a": 435,
    "i": 30,
    "m": 4013.38,
    "s": 1052.7242733023686
  },
  {
    "v": 40,
    "a": 780,
    "i": 40,
    "m": 5693.64,
    "s": 1888.617714202639
  },
  {
    "v": 50,
    "a": 1225,
    "i": 50,
    "m": 6661.56,
    "s": 1287.2641711785502
  },
  {
    "v": 60,
    "a": 1770,
    "i": 60,
    "m": 7598.98,
    "s": 1545.960717353452
  },
  {
    "v": 70,
    "a": 2415,
    "i": 70,
    "m": 9666.36,
    "s": 1635.124285918352
  },
  {
    "v": 80,
    "a": 3160,
    "i": 80,
    "m": 12657.32,
    "s": 2000.9120464428215
  },
  {
    "v": 90,
    "a": 4005,
    "i": 90,
    "m": 15679.74,
    "s": 2579.483132800058
  },
  {
    "v": 100,
    "a": 4950,
    "i": 100,
    "m": 20587.66,
    "s": 2950.0804979525556
  }
]


figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')

mean = np.array(list(map(lambda e: e['m'], data)))
std = np.array(list(map(lambda e: e['s'], data)))
amv = np.array(list(map(lambda e: e['a']+e['v'], data)))

plt.plot(amv, mean, color='green', marker='o',linewidth=3, markersize=10, label="Média")
plt.plot(amv, std, color='blue', marker='o',linewidth=3, markersize=10, label="Desvio padrão")
plt.plot(amv, 4*amv+4000, color='red',linewidth=1, label="O(n+m)")

plt.xticks(amv)
plt.ylabel('Tempo de execução (microssegundos)',fontsize=14)
plt.xlabel('Vértices + Arestas',fontsize=14)

plt.legend()
plt.show()
